# %% [markdown]
# # MLP Classifier

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.feature_selection import SelectKBest, VarianceThreshold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.neural_network import MLPClassifier

from common import load_image, show_image, load_data, split_data, validation_scores

# %%
# Load data
df = load_data()

# Split data
X_train, X_test, y_train, y_test = split_data(df)
# Preview shape of split data
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (5335, 256) (5335,) (1334, 256) (1334,)

# %% [markdown]
# ### MLPClassifier Mini test results
# 4 options: 4m 2.6s

# %%
# Setup a pipeline for a strict ordering operations (and names for defining param grids)
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Placehold for Scalers
    ('pca', PCA()),  # Placeholder for PCA
    ('clustering', KMeans()),  # Placeholder for KMeans
    ('feature_selection', SelectKBest()),  # Placeholder for feature selection
    ('mlp', MLPClassifier(random_state=0, max_iter=1000))  # placeholder for MLPClassifier
])

# These parameters will be the same for each of the separate cases defined later
param_grid = {
    # Scaler: 2 methods
    'scaler': [StandardScaler(), MinMaxScaler()],  # 2 normalization methods,
    'pca': [PCA(n_components=8), PCA(n_components=16)],
    # Clustering: 2 methods
    # Feature Selection: 2 methods + 1 (no method)
    'feature_selection': [
        SelectKBest(k=4),
        VarianceThreshold(threshold=0.2)
    ],
    # MLP parameters
    'mlp__hidden_layer_sizes': [(50,), (50, 50)],
    'mlp__activation': ['relu', 'tanh'],
    'mlp__solver': ['adam', 'sgd'],
    'mlp__alpha': [0.0001, 0.01],
}

results = validation_scores(pipe, param_grid, X_train, y_train)
for scorer_name, scorer_results in results.items():
    print(scorer_name)
    print(scorer_results)
# Out:
# Fitting 4 folds for each of 128 candidates, totalling 512 fits
# Fitting 4 folds for each of 128 candidates, totalling 512 fits
# Fitting 4 folds for each of 128 candidates, totalling 512 fits
# accuracy
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         3.101259      0.541920         0.012127        0.000738
# 1         5.194201      0.778228         0.014000        0.003535
# 2         3.359698      0.926096         0.014311        0.001338
# 3         4.766748      0.742495         0.020209        0.006023
# 4         2.027296      0.444436         0.021248        0.012616
# ..             ...           ...              ...             ...
# 123       5.098152      0.782760         0.021908        0.006516
# 124       2.856528      0.801528         0.020543        0.002640
# 125       6.070291      0.999720         0.013250        0.003701
# 126       2.085819      0.412870         0.030500        0.018821
# 127       5.087280      0.692615         0.011251        0.002859
#
#               param_feature_selection param_mlp__activation param_mlp__alpha  \
# 0                    SelectKBest(k=4)                  relu           0.0001
# 1                    SelectKBest(k=4)                  relu           0.0001
# 2                    SelectKBest(k=4)                  relu           0.0001
# 3                    SelectKBest(k=4)                  relu           0.0001
# 4                    SelectKBest(k=4)                  relu           0.0001
# ..                                ...                   ...              ...
# 123  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 124  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 125  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 126  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 127  VarianceThreshold(threshold=0.2)                  tanh             0.01
#
#     param_mlp__hidden_layer_sizes param_mlp__solver             param_pca  \
# 0                           (50,)              adam   PCA(n_components=8)
# 1                           (50,)              adam   PCA(n_components=8)
# 2                           (50,)              adam  PCA(n_components=16)
# 3                           (50,)              adam  PCA(n_components=16)
# 4                           (50,)               sgd   PCA(n_components=8)
# ..                            ...               ...                   ...
# 123                      (50, 50)              adam  PCA(n_components=16)
# 124                      (50, 50)               sgd   PCA(n_components=8)
# 125                      (50, 50)               sgd   PCA(n_components=8)
# 126                      (50, 50)               sgd  PCA(n_components=16)
# 127                      (50, 50)               sgd  PCA(n_components=16)
#
#          param_scaler                                             params  \
# 0    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 1      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 2    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 3      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 4    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# ..                ...                                                ...
# 123    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 124  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 125    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 126  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 127    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.871064           0.871814           0.885307
# 1             0.882309           0.876312           0.892054
# 2             0.885307           0.871064           0.886807
# 3             0.888306           0.877811           0.888306
# 4             0.874813           0.869565           0.880060
# ..                 ...                ...                ...
# 123           0.902549           0.889805           0.899550
# 124           0.902549           0.892054           0.849325
# 125           0.894303           0.885307           0.904798
# 126           0.898801           0.883058           0.889055
# 127           0.898051           0.885307           0.904048
#
#      split3_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.882221         0.877602        0.006264              105
# 1             0.890473         0.885287        0.006366               81
# 2             0.882971         0.881537        0.006199               92
# 3             0.888222         0.885661        0.004532               80
# 4             0.881470         0.876477        0.004699              109
# ..                 ...              ...             ...              ...
# 123           0.904726         0.899158        0.005704               15
# 124           0.904726         0.887164        0.022365               72
# 125           0.903226         0.896908        0.007803               38
# 126           0.900975         0.892972        0.007274               58
# 127           0.903226         0.897658        0.007492               31
#
# [128 rows x 19 columns]
# roc_auc
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         3.330006      0.561883         0.019246        0.004147
# 1         5.590660      0.962273         0.016684        0.000894
# 2         3.044005      0.320002         0.018249        0.000434
# 3         5.067999      0.419835         0.018499        0.002692
# 4         1.782499      0.504068         0.017498        0.001120
# ..             ...           ...              ...             ...
# 123       3.204070      0.781832         0.021777        0.002400
# 124       2.071033      0.961182         0.029911        0.009288
# 125       4.428083      1.193417         0.013000        0.002119
# 126       2.326230      0.796927         0.019194        0.005403
# 127       4.531173      0.773476         0.011735        0.001885
#
#               param_feature_selection param_mlp__activation param_mlp__alpha  \
# 0                    SelectKBest(k=4)                  relu           0.0001
# 1                    SelectKBest(k=4)                  relu           0.0001
# 2                    SelectKBest(k=4)                  relu           0.0001
# 3                    SelectKBest(k=4)                  relu           0.0001
# 4                    SelectKBest(k=4)                  relu           0.0001
# ..                                ...                   ...              ...
# 123  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 124  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 125  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 126  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 127  VarianceThreshold(threshold=0.2)                  tanh             0.01
#
#     param_mlp__hidden_layer_sizes param_mlp__solver             param_pca  \
# 0                           (50,)              adam   PCA(n_components=8)
# 1                           (50,)              adam   PCA(n_components=8)
# 2                           (50,)              adam  PCA(n_components=16)
# 3                           (50,)              adam  PCA(n_components=16)
# 4                           (50,)               sgd   PCA(n_components=8)
# ..                            ...               ...                   ...
# 123                      (50, 50)              adam  PCA(n_components=16)
# 124                      (50, 50)               sgd   PCA(n_components=8)
# 125                      (50, 50)               sgd   PCA(n_components=8)
# 126                      (50, 50)               sgd  PCA(n_components=16)
# 127                      (50, 50)               sgd  PCA(n_components=16)
#
#          param_scaler                                             params  \
# 0    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 1      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 2    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 3      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 4    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# ..                ...                                                ...
# 123    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 124  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 125    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 126  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 127    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.977485           0.980849           0.983685
# 1             0.981712           0.982544           0.984122
# 2             0.983405           0.980733           0.982885
# 3             0.981846           0.981290           0.983969
# 4             0.978023           0.980939           0.978446
# ..                 ...                ...                ...
# 123           0.986598           0.985263           0.987856
# 124           0.982800           0.979110           0.985089
# 125           0.986529           0.984682           0.987768
# 126           0.985967           0.979657           0.986528
# 127           0.986524           0.984631           0.987967
#
#      split3_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.980268         0.980572        0.002202              105
# 1             0.983159         0.982884        0.000880               73
# 2             0.979798         0.981705        0.001489               92
# 3             0.983066         0.982543        0.001044               75
# 4             0.972589         0.977499        0.003046              120
# ..                 ...              ...             ...              ...
# 123           0.987570         0.986822        0.001014               13
# 124           0.987192         0.983548        0.002996               66
# 125           0.987006         0.986496        0.001137               32
# 126           0.985081         0.984308        0.002735               62
# 127           0.986739         0.986465        0.001194               38
#
# [128 rows x 19 columns]
# f1_score
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         3.044315      0.538690         0.013567        0.002252
# 1         4.795701      0.702479         0.015186        0.001689
# 2         3.637700      0.416751         0.015552        0.003164
# 3         5.034776      0.629591         0.015428        0.001894
# 4         1.936794      0.921246         0.016050        0.003529
# ..             ...           ...              ...             ...
# 123       3.102066      0.589950         0.022002        0.002403
# 124       2.030383      0.312773         0.021565        0.004609
# 125       4.502014      1.104424         0.011250        0.002486
# 126       1.964683      0.356897         0.018143        0.003900
# 127       3.838223      0.968517         0.010501        0.002291
#
#               param_feature_selection param_mlp__activation param_mlp__alpha  \
# 0                    SelectKBest(k=4)                  relu           0.0001
# 1                    SelectKBest(k=4)                  relu           0.0001
# 2                    SelectKBest(k=4)                  relu           0.0001
# 3                    SelectKBest(k=4)                  relu           0.0001
# 4                    SelectKBest(k=4)                  relu           0.0001
# ..                                ...                   ...              ...
# 123  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 124  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 125  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 126  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 127  VarianceThreshold(threshold=0.2)                  tanh             0.01
#
#     param_mlp__hidden_layer_sizes param_mlp__solver             param_pca  \
# 0                           (50,)              adam   PCA(n_components=8)
# 1                           (50,)              adam   PCA(n_components=8)
# 2                           (50,)              adam  PCA(n_components=16)
# 3                           (50,)              adam  PCA(n_components=16)
# 4                           (50,)               sgd   PCA(n_components=8)
# ..                            ...               ...                   ...
# 123                      (50, 50)              adam  PCA(n_components=16)
# 124                      (50, 50)               sgd   PCA(n_components=8)
# 125                      (50, 50)               sgd   PCA(n_components=8)
# 126                      (50, 50)               sgd  PCA(n_components=16)
# 127                      (50, 50)               sgd  PCA(n_components=16)
#
#          param_scaler                                             params  \
# 0    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 1      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 2    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 3      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 4    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# ..                ...                                                ...
# 123    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 124  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 125    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 126  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 127    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.876823           0.876144           0.877977
# 1             0.888222           0.878204           0.886196
# 2             0.878273           0.873722           0.885597
# 3             0.887555           0.878152           0.891247
# 4             0.832653           0.871920           0.879723
# ..                 ...                ...                ...
# 123           0.903497           0.886974           0.899666
# 124           0.904301           0.888700           0.898217
# 125           0.895025           0.887781           0.902617
# 126           0.901249           0.893881           0.896047
# 127           0.895072           0.886998           0.902539
#
#      split3_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.877044         0.876997        0.000656              100
# 1             0.889529         0.885538        0.004398               80
# 2             0.884431         0.880506        0.004804               93
# 3             0.891775         0.887182        0.005461               72
# 4             0.826198         0.852624        0.023473              123
# ..                 ...              ...             ...              ...
# 123           0.904866         0.898751        0.007061               23
# 124           0.907120         0.899584        0.007060               11
# 125           0.905639         0.897765        0.006941               34
# 126           0.899508         0.897671        0.002880               36
# 127           0.904097         0.897177        0.006795               46
#
# [128 rows x 19 columns]

# %%
import pandas as pd

dataframes = []
for key, df in results.items():
    df['scorer'] = key
    dataframes.append(df)
    
merged_df = pd.concat(dataframes, ignore_index=True)
merged_df.to_csv('mlp_results.csv', index=False)
merged_df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         3.101259      0.541920         0.012127        0.000738
# 1         5.194201      0.778228         0.014000        0.003535
# 2         3.359698      0.926096         0.014311        0.001338
# 3         4.766748      0.742495         0.020209        0.006023
# 4         2.027296      0.444436         0.021248        0.012616
# ..             ...           ...              ...             ...
# 379       3.102066      0.589950         0.022002        0.002403
# 380       2.030383      0.312773         0.021565        0.004609
# 381       4.502014      1.104424         0.011250        0.002486
# 382       1.964683      0.356897         0.018143        0.003900
# 383       3.838223      0.968517         0.010501        0.002291
#
#               param_feature_selection param_mlp__activation param_mlp__alpha  \
# 0                    SelectKBest(k=4)                  relu           0.0001
# 1                    SelectKBest(k=4)                  relu           0.0001
# 2                    SelectKBest(k=4)                  relu           0.0001
# 3                    SelectKBest(k=4)                  relu           0.0001
# 4                    SelectKBest(k=4)                  relu           0.0001
# ..                                ...                   ...              ...
# 379  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 380  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 381  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 382  VarianceThreshold(threshold=0.2)                  tanh             0.01
# 383  VarianceThreshold(threshold=0.2)                  tanh             0.01
#
#     param_mlp__hidden_layer_sizes param_mlp__solver             param_pca  \
# 0                           (50,)              adam   PCA(n_components=8)
# 1                           (50,)              adam   PCA(n_components=8)
# 2                           (50,)              adam  PCA(n_components=16)
# 3                           (50,)              adam  PCA(n_components=16)
# 4                           (50,)               sgd   PCA(n_components=8)
# ..                            ...               ...                   ...
# 379                      (50, 50)              adam  PCA(n_components=16)
# 380                      (50, 50)               sgd   PCA(n_components=8)
# 381                      (50, 50)               sgd   PCA(n_components=8)
# 382                      (50, 50)               sgd  PCA(n_components=16)
# 383                      (50, 50)               sgd  PCA(n_components=16)
#
#          param_scaler                                             params  \
# 0    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 1      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 2    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 3      MinMaxScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# 4    StandardScaler()  {'feature_selection': SelectKBest(k=4), 'mlp__...
# ..                ...                                                ...
# 379    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 380  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 381    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
# 382  StandardScaler()  {'feature_selection': VarianceThreshold(thresh...
# 383    MinMaxScaler()  {'feature_selection': VarianceThreshold(thresh...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.871064           0.871814           0.885307
# 1             0.882309           0.876312           0.892054
# 2             0.885307           0.871064           0.886807
# 3             0.888306           0.877811           0.888306
# 4             0.874813           0.869565           0.880060
# ..                 ...                ...                ...
# 379           0.903497           0.886974           0.899666
# 380           0.904301           0.888700           0.898217
# 381           0.895025           0.887781           0.902617
# 382           0.901249           0.893881           0.896047
# 383           0.895072           0.886998           0.902539
#
#      split3_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0             0.882221         0.877602        0.006264              105
# 1             0.890473         0.885287        0.006366               81
# 2             0.882971         0.881537        0.006199               92
# 3             0.888222         0.885661        0.004532               80
# 4             0.881470         0.876477        0.004699              109
# ..                 ...              ...             ...              ...
# 379           0.904866         0.898751        0.007061               23
# 380           0.907120         0.899584        0.007060               11
# 381           0.905639         0.897765        0.006941               34
# 382           0.899508         0.897671        0.002880               36
# 383           0.904097         0.897177        0.006795               46
#
#        scorer
# 0    accuracy
# 1    accuracy
# 2    accuracy
# 3    accuracy
# 4    accuracy
# ..        ...
# 379  f1_score
# 380  f1_score
# 381  f1_score
# 382  f1_score
# 383  f1_score
#
# [384 rows x 20 columns]
