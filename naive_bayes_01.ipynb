# %% [markdown]
# # Naive Bayes Classifier

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.feature_selection import SelectKBest, VarianceThreshold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.naive_bayes import GaussianNB

from common import load_image, show_image, load_data, split_data, validation_scores, merge_results

# %%
# Directory to save results
results_dir = 'naive_bayes_results'

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    print(f'Results directory "{results_dir}" created')
else:
    print(f'Results directory "{results_dir}" already exists')
# Out:
# Results directory "naive_bayes_results" already exists

# %%
# Load data
df = load_data()

# Split data
X_train, X_test, y_train, y_test = split_data(df)
# Preview shape of split data
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (5335, 256) (5335,) (1334, 256) (1334,)

# %%
# Setup a pipeline for a strict ordering operations (and names for defining param grids)
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Placehold for Scalers
    ('pca', PCA()),  # Placeholder for PCA
    ('feature_selection', SelectKBest()),  # Placeholder for feature selection
    ('gnb', GaussianNB())  # placeholder for MLPClassifier
])

# These parameters will be the same for each of the separate cases defined later
param_grid = {
    # Scaler: 2 normalization methods
    'scaler': [StandardScaler(), MinMaxScaler()],
    # Principal component analysis
    'pca': [
        PCA(n_components=8),
        PCA(n_components=16),
        PCA(n_components=32),
        PCA(n_components=64),
        PCA(n_components=64),
        PCA(n_components=128),
        None,
    ],
    # Feature Selection: 2 methods + 1 (no method)
    'feature_selection': [
        # VarianceThreshold(threshold=0.1),  # No feature meets this threshold
        VarianceThreshold(threshold=0.2),
        VarianceThreshold(threshold=0.4),
        VarianceThreshold(threshold=0.6),
        VarianceThreshold(threshold=0.8),
        None,
    ],
    # No tunable hyperparamters for GaussianNB
}

results = validation_scores(pipe, param_grid, X_train, y_train, verbose=3)
for scorer_name, scorer_results in results.items():
    print(scorer_name)
    print(scorer_results)
# Out:
# Fitting 4 folds for each of 70 candidates, totalling 280 fits
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 16 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.20000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.40000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.60000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.80000
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.87722638 0.86410513 0.87722638 0.86410513 0.87722638 0.86410513
#  0.87722638 0.86410513 0.87722638 0.86410513 0.87722638 0.86410513
#  0.86073069        nan 0.87760119 0.86410513 0.87760119 0.86410513
#  0.87760119 0.86410513 0.87760119 0.86410513 0.87760119 0.86410513
#  0.87760119 0.86410513 0.86073069        nan 0.87104113 0.85023467
#  0.87104113 0.85023467 0.87104113 0.85023467 0.87104113 0.85023467
#  0.87104113 0.85023467 0.87104113 0.85023467 0.86073069        nan
#  0.87104113 0.85023467 0.87104113 0.85023467 0.87104113 0.85023467
#  0.87104113 0.85023467 0.87104113 0.85023467 0.87104113 0.85023467
#  0.86073069        nan 0.87722638 0.87347713 0.8432998  0.84236248
#  0.78313085 0.77975641 0.75445136 0.74376653 0.75445108 0.7458287
#  0.71508844 0.70159294 0.86073069 0.86073069]
#   warnings.warn(
# Fitting 4 folds for each of 70 candidates, totalling 280 fits
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 16 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.20000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.40000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.60000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.80000
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.98262924 0.98174685 0.98262983 0.98174685 0.98262978 0.98174685
#  0.9826295  0.98174685 0.98262962 0.98174685 0.9826297  0.98174685
#  0.97520682        nan 0.98262385 0.98174685 0.98262385 0.98174685
#  0.98262352 0.98174685 0.98262385 0.98174685 0.98262385 0.98174685
#  0.98262385 0.98174685 0.97520682        nan 0.98237412 0.9780717
#  0.98237412 0.9780717  0.98237412 0.9780717  0.98237412 0.9780717
#  0.98237412 0.9780717  0.98237412 0.9780717  0.97520682        nan
#  0.98237412 0.9780717  0.98237412 0.9780717  0.98237412 0.9780717
#  0.98237412 0.9780717  0.98237412 0.9780717  0.98237412 0.9780717
#  0.97520682        nan 0.9826295  0.98211776 0.98202609 0.98164973
#  0.97616975 0.97633467 0.95242645 0.95474571 0.95254962 0.95471034
#  0.91015023 0.91077111 0.97520682 0.97522206]
#   warnings.warn(
# Fitting 4 folds for each of 70 candidates, totalling 280 fits
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 16 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.20000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.40000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.60000
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\sande\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "c:\Users\sande\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py", line 120, in fit
#     raise ValueError(msg.format(self.threshold))
# ValueError: No feature in X meets the variance threshold 0.80000
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\sande\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.87768461 0.86441073 0.87768461 0.86441073 0.87768461 0.86441073
#  0.87768461 0.86441073 0.87768461 0.86441073 0.87768461 0.86441073
#  0.86051222        nan 0.87796535 0.86441073 0.87796535 0.86441073
#  0.87796535 0.86441073 0.87796535 0.86441073 0.87796535 0.86441073
#  0.87796535 0.86441073 0.86051222        nan 0.87146448 0.85065354
#  0.87146448 0.85065354 0.87146448 0.85065354 0.87146448 0.85065354
#  0.87146448 0.85065354 0.87146448 0.85065354 0.86051222        nan
#  0.87146448 0.85065354 0.87146448 0.85065354 0.87146448 0.85065354
#  0.87146448 0.85065354 0.87146448 0.85065354 0.87146448 0.85065354
#  0.86051222        nan 0.87768461 0.87406187 0.84296601 0.84069018
#  0.78074173 0.7729527  0.74592447 0.73733006 0.74486406 0.73486783
#  0.70868782 0.69676002 0.86051222 0.86051222]
#   warnings.warn(
# accuracy
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.336000      0.051130         0.025030        0.005112
# 1        0.444397      0.041159         0.024009        0.003261
# 2        0.580381      0.024130         0.044122        0.010910
# 3        0.546144      0.022720         0.036302        0.005771
# 4        0.509896      0.032069         0.040430        0.005667
# ..            ...           ...              ...             ...
# 65       1.205175      0.338277         0.038027        0.009383
# 66       1.084683      0.078109         0.109263        0.027594
# 67       0.942559      0.075672         0.054252        0.011693
# 68       0.299403      0.125932         0.106505        0.037448
# 69       0.339498      0.122171         0.097499        0.016652
#
#              param_feature_selection              param_pca      param_scaler  \
# 0   VarianceThreshold(threshold=0.2)    PCA(n_components=8)  StandardScaler()
# 1   VarianceThreshold(threshold=0.2)    PCA(n_components=8)    MinMaxScaler()
# 2   VarianceThreshold(threshold=0.2)   PCA(n_components=16)  StandardScaler()
# 3   VarianceThreshold(threshold=0.2)   PCA(n_components=16)    MinMaxScaler()
# 4   VarianceThreshold(threshold=0.2)   PCA(n_components=32)  StandardScaler()
# ..                               ...                    ...               ...
# 65                              None   PCA(n_components=64)    MinMaxScaler()
# 66                              None  PCA(n_components=128)  StandardScaler()
# 67                              None  PCA(n_components=128)    MinMaxScaler()
# 68                              None                   None  StandardScaler()
# 69                              None                   None    MinMaxScaler()
#
#                                                params  split0_test_score  \
# 0   {'feature_selection': VarianceThreshold(thresh...           0.868066
# 1   {'feature_selection': VarianceThreshold(thresh...           0.847076
# 2   {'feature_selection': VarianceThreshold(thresh...           0.868066
# 3   {'feature_selection': VarianceThreshold(thresh...           0.847076
# 4   {'feature_selection': VarianceThreshold(thresh...           0.868066
# ..                                                ...                ...
# 65  {'feature_selection': None, 'pca': PCA(n_compo...           0.732384
# 66  {'feature_selection': None, 'pca': PCA(n_compo...           0.700900
# 67  {'feature_selection': None, 'pca': PCA(n_compo...           0.692654
# 68  {'feature_selection': None, 'pca': None, 'scal...           0.852324
# 69  {'feature_selection': None, 'pca': None, 'scal...           0.852324
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0            0.881559           0.879310           0.879970         0.877226
# 1            0.871814           0.872564           0.864966         0.864105
# 2            0.881559           0.879310           0.879970         0.877226
# 3            0.871814           0.872564           0.864966         0.864105
# 4            0.881559           0.879310           0.879970         0.877226
# ..                ...                ...                ...              ...
# 65           0.751874           0.757121           0.741935         0.745829
# 66           0.714393           0.733133           0.711928         0.715088
# 67           0.702399           0.711394           0.699925         0.701593
# 68           0.857571           0.874063           0.858965         0.860731
# 69           0.857571           0.874063           0.858965         0.860731
#
#     std_test_score  rank_test_score
# 0         0.005352                7
# 1         0.010268               27
# 2         0.005352                7
# 3         0.010268               27
# 4         0.005352                7
# ..             ...              ...
# 65        0.009487               63
# 66        0.011591               65
# 67        0.006697               66
# 68        0.008086               39
# 69        0.008086               39
#
# [70 rows x 15 columns]
# roc_auc
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.746269      0.206887         0.041498        0.018202
# 1        0.559999      0.054848         0.047253        0.012336
# 2        0.751019      0.205066         0.042502        0.003204
# 3        0.715019      0.164145         0.049256        0.006385
# 4        0.542536      0.061470         0.053504        0.008077
# ..            ...           ...              ...             ...
# 65       0.713549      0.072112         0.067505        0.011542
# 66       1.001971      0.050433         0.054147        0.014709
# 67       0.907685      0.022427         0.034402        0.005040
# 68       0.264999      0.035691         0.125006        0.014711
# 69       0.230003      0.011554         0.102907        0.027852
#
#              param_feature_selection              param_pca      param_scaler  \
# 0   VarianceThreshold(threshold=0.2)    PCA(n_components=8)  StandardScaler()
# 1   VarianceThreshold(threshold=0.2)    PCA(n_components=8)    MinMaxScaler()
# 2   VarianceThreshold(threshold=0.2)   PCA(n_components=16)  StandardScaler()
# 3   VarianceThreshold(threshold=0.2)   PCA(n_components=16)    MinMaxScaler()
# 4   VarianceThreshold(threshold=0.2)   PCA(n_components=32)  StandardScaler()
# ..                               ...                    ...               ...
# 65                              None   PCA(n_components=64)    MinMaxScaler()
# 66                              None  PCA(n_components=128)  StandardScaler()
# 67                              None  PCA(n_components=128)    MinMaxScaler()
# 68                              None                   None  StandardScaler()
# 69                              None                   None    MinMaxScaler()
#
#                                                params  split0_test_score  \
# 0   {'feature_selection': VarianceThreshold(thresh...           0.981876
# 1   {'feature_selection': VarianceThreshold(thresh...           0.980824
# 2   {'feature_selection': VarianceThreshold(thresh...           0.981876
# 3   {'feature_selection': VarianceThreshold(thresh...           0.980824
# 4   {'feature_selection': VarianceThreshold(thresh...           0.981877
# ..                                                ...                ...
# 65  {'feature_selection': None, 'pca': PCA(n_compo...           0.948333
# 66  {'feature_selection': None, 'pca': PCA(n_compo...           0.904635
# 67  {'feature_selection': None, 'pca': PCA(n_compo...           0.904988
# 68  {'feature_selection': None, 'pca': None, 'scal...           0.973814
# 69  {'feature_selection': None, 'pca': None, 'scal...           0.973814
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0            0.982053           0.983194           0.983395         0.982629
# 1            0.980973           0.982988           0.982203         0.981747
# 2            0.982053           0.983194           0.983396         0.982630
# 3            0.980973           0.982988           0.982203         0.981747
# 4            0.982052           0.983195           0.983396         0.982630
# ..                ...                ...                ...              ...
# 65           0.953604           0.962803           0.954102         0.954710
# 66           0.904067           0.923031           0.908867         0.910150
# 67           0.905915           0.923305           0.908877         0.910771
# 68           0.973449           0.978273           0.975291         0.975207
# 69           0.973431           0.978269           0.975375         0.975222
#
#     std_test_score  rank_test_score
# 0         0.000672                7
# 1         0.000894               28
# 2         0.000672                1
# 3         0.000894               28
# 4         0.000672                2
# ..             ...              ...
# 65        0.005191               62
# 66        0.007665               66
# 67        0.007377               65
# 68        0.001900               56
# 69        0.001904               55
#
# [70 rows x 15 columns]
# f1_score
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.635002      0.071795         0.041037        0.013750
# 1        0.536251      0.065197         0.033501        0.005314
# 2        0.612749      0.061280         0.052795        0.007532
# 3        0.598004      0.042053         0.046743        0.004085
# 4        0.568844      0.083358         0.038275        0.008095
# ..            ...           ...              ...             ...
# 65       0.728954      0.035507         0.052312        0.004711
# 66       0.931266      0.063238         0.044880        0.008099
# 67       0.848601      0.045367         0.026749        0.008640
# 68       0.274279      0.036825         0.113767        0.004462
# 69       0.245701      0.038576         0.115625        0.005409
#
#              param_feature_selection              param_pca      param_scaler  \
# 0   VarianceThreshold(threshold=0.2)    PCA(n_components=8)  StandardScaler()
# 1   VarianceThreshold(threshold=0.2)    PCA(n_components=8)    MinMaxScaler()
# 2   VarianceThreshold(threshold=0.2)   PCA(n_components=16)  StandardScaler()
# 3   VarianceThreshold(threshold=0.2)   PCA(n_components=16)    MinMaxScaler()
# 4   VarianceThreshold(threshold=0.2)   PCA(n_components=32)  StandardScaler()
# ..                               ...                    ...               ...
# 65                              None   PCA(n_components=64)    MinMaxScaler()
# 66                              None  PCA(n_components=128)  StandardScaler()
# 67                              None  PCA(n_components=128)    MinMaxScaler()
# 68                              None                   None  StandardScaler()
# 69                              None                   None    MinMaxScaler()
#
#                                                params  split0_test_score  \
# 0   {'feature_selection': VarianceThreshold(thresh...           0.868165
# 1   {'feature_selection': VarianceThreshold(thresh...           0.846585
# 2   {'feature_selection': VarianceThreshold(thresh...           0.868165
# 3   {'feature_selection': VarianceThreshold(thresh...           0.846585
# 4   {'feature_selection': VarianceThreshold(thresh...           0.868165
# ..                                                ...                ...
# 65  {'feature_selection': None, 'pca': PCA(n_compo...           0.712094
# 66  {'feature_selection': None, 'pca': PCA(n_compo...           0.690770
# 67  {'feature_selection': None, 'pca': PCA(n_compo...           0.676906
# 68  {'feature_selection': None, 'pca': None, 'scal...           0.851625
# 69  {'feature_selection': None, 'pca': None, 'scal...           0.851625
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0            0.882134           0.879890           0.880549         0.877685
# 1            0.872453           0.873175           0.865430         0.864411
# 2            0.882134           0.879890           0.880549         0.877685
# 3            0.872453           0.873175           0.865430         0.864411
# 4            0.882134           0.879890           0.880549         0.877685
# ..                ...                ...                ...              ...
# 65           0.740739           0.753361           0.733278         0.734868
# 66           0.707827           0.726990           0.709163         0.708688
# 67           0.700465           0.713289           0.696380         0.696760
# 68           0.857478           0.874435           0.858511         0.860512
# 69           0.857478           0.874435           0.858511         0.860512
#
#     std_test_score  rank_test_score
# 0         0.005556                7
# 1         0.010727               27
# 2         0.005556                7
# 3         0.010727               27
# 4         0.005556                7
# ..             ...              ...
# 65        0.014980               64
# 66        0.012816               65
# 67        0.013050               66
# 68        0.008456               39
# 69        0.008456               39
#
# [70 rows x 15 columns]

# %%
mdf = merge_results(results)

# Remove entries for fits that failed
mdf = mdf[~mdf['mean_test_score'].isna()]
mdf.head()

# Save merged results to csv file
mdf.to_csv(os.path.join(results_dir, 'gnb_results.csv'), index=False)

# %%
# Get top scoring for each scorer method
top_each = pd.concat([
    mdf[mdf['scorer']==scorer].sort_values(by='rank_test_score').head(3)
    for scorer in sorted(mdf['scorer'].unique())
], ignore_index=True)

# Save top 3 performing models for each scorers (9 total results, but likely fewer than 9 unique param options)
top_each.to_csv(os.path.join(results_dir, 'top_3_per_scorer.csv'), index=False)

top_each
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.576683      0.026490         0.036005        0.005098
# 1       0.687598      0.090507         0.035748        0.010782
# 2       1.140128      0.070333         0.051755        0.007523
# 3       0.552957      0.038427         0.046578        0.008779
# 4       0.622134      0.052201         0.037324        0.007792
# 5       1.102552      0.045036         0.044763        0.003061
# 6       0.751019      0.205066         0.042502        0.003204
# 7       0.542536      0.061470         0.053504        0.008077
# 8       1.091359      0.094195         0.055502        0.004923
#
#             param_feature_selection              param_pca      param_scaler  \
# 0  VarianceThreshold(threshold=0.4)   PCA(n_components=32)  StandardScaler()
# 1  VarianceThreshold(threshold=0.4)    PCA(n_components=8)  StandardScaler()
# 2  VarianceThreshold(threshold=0.4)  PCA(n_components=128)  StandardScaler()
# 3  VarianceThreshold(threshold=0.4)   PCA(n_components=32)  StandardScaler()
# 4  VarianceThreshold(threshold=0.4)    PCA(n_components=8)  StandardScaler()
# 5  VarianceThreshold(threshold=0.4)  PCA(n_components=128)  StandardScaler()
# 6  VarianceThreshold(threshold=0.2)   PCA(n_components=16)  StandardScaler()
# 7  VarianceThreshold(threshold=0.2)   PCA(n_components=32)  StandardScaler()
# 8  VarianceThreshold(threshold=0.2)  PCA(n_components=128)  StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'feature_selection': VarianceThreshold(thresh...           0.866567
# 1  {'feature_selection': VarianceThreshold(thresh...           0.866567
# 2  {'feature_selection': VarianceThreshold(thresh...           0.866567
# 3  {'feature_selection': VarianceThreshold(thresh...           0.866571
# 4  {'feature_selection': VarianceThreshold(thresh...           0.866571
# 5  {'feature_selection': VarianceThreshold(thresh...           0.866571
# 6  {'feature_selection': VarianceThreshold(thresh...           0.981876
# 7  {'feature_selection': VarianceThreshold(thresh...           0.981877
# 8  {'feature_selection': VarianceThreshold(thresh...           0.981876
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.884558           0.879310           0.879970         0.877601
# 1           0.884558           0.879310           0.879970         0.877601
# 2           0.884558           0.879310           0.879970         0.877601
# 3           0.885060           0.879819           0.880411         0.877965
# 4           0.885060           0.879819           0.880411         0.877965
# 5           0.885060           0.879819           0.880411         0.877965
# 6           0.982053           0.983194           0.983396         0.982630
# 7           0.982052           0.983195           0.983396         0.982630
# 8           0.982053           0.983194           0.983396         0.982630
#
#    std_test_score  rank_test_score    scorer
# 0        0.006684                1  accuracy
# 1        0.006684                1  accuracy
# 2        0.006684                1  accuracy
# 3        0.006884                1  f1_score
# 4        0.006884                1  f1_score
# 5        0.006884                1  f1_score
# 6        0.000672                1   roc_auc
# 7        0.000672                2   roc_auc
# 8        0.000672                3   roc_auc

# %%
"""
Best model parameters from results is as follows:
{
    'feature_selection': VarianceThreshold(threshold=0.4),
    'pca': PCA(n_components=32),
    'scaler': StandardScaler()
}

"""
best_params = top_each.iloc[0]['params']
best_params
# Out:
# {'feature_selection': VarianceThreshold(threshold=0.4),
#  'pca': PCA(n_components=32),
#  'scaler': StandardScaler()}

# %%
# Results for all scoring methods for chosen best model
best_model_scores = mdf[mdf['params']==best_params]

# Save all 3 results for best model (3x different scorer methods)
best_model_scores.to_csv(os.path.join(results_dir, 'best_model_params_and_scores.csv'))

# Show all 3 scores for best model params
best_model_scores
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 18        0.576683      0.026490         0.036005        0.005098
# 88        0.634748      0.068854         0.052251        0.008377
# 158       0.552957      0.038427         0.046578        0.008779
#
#               param_feature_selection             param_pca      param_scaler  \
# 18   VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
# 88   VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
# 158  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
#
#                                                 params  split0_test_score  \
# 18   {'feature_selection': VarianceThreshold(thresh...           0.866567
# 88   {'feature_selection': VarianceThreshold(thresh...           0.981895
# 158  {'feature_selection': VarianceThreshold(thresh...           0.866571
#
#      split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 18            0.884558           0.879310           0.879970         0.877601
# 88            0.981951           0.983106           0.983542         0.982624
# 158           0.885060           0.879819           0.880411         0.877965
#
#      std_test_score  rank_test_score    scorer
# 18         0.006684                1  accuracy
# 88         0.000718               13   roc_auc
# 158        0.006884                1  f1_score

# %%
for scorer in sorted(best_model_scores['scorer'].unique()):
    mean_test_score = best_model_scores[best_model_scores['scorer']==scorer]['mean_test_score'].values[0]
    print(f'{scorer}: {mean_test_score:.4%}')
# Out:
# accuracy: 87.7601%
# f1_score: 87.7965%
# roc_auc: 98.2624%

# %%
# Try a couple clustering options with the best model params
kmeans = KMeans(n_clusters=5, random_state=0)

X_train_clust = X_train.copy()
X_train_clust['cluster'] = kmeans.fit_predict(X_train)

X_test_clust = X_test.copy()
X_test_clust['cluster'] = kmeans.predict(X_test)

# %%
# Best model
# Setup a pipeline for a strict ordering operations (and names for defining param grids)
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Placehold for Scalers
    ('pca', PCA()),  # Placeholder for PCA
    ('feature_selection', VarianceThreshold()),  # Placeholder for feature selection
    ('gnb', GaussianNB())  # placeholder for MLPClassifier
])

# These parameters will be the same for each of the separate cases defined later
param_grid = {
    # Scaler: 2 normalization methods
    'scaler': [StandardScaler()],
    # Principal component analysis
    'pca': [
        PCA(n_components=32),
    ],
    # Feature Selection: 2 methods + 1 (no method)
    'feature_selection': [
        VarianceThreshold(threshold=0.4),
    ],
    # No tunable hyperparamters for GaussianNB
}

results_clust, best_params_clust = validation_scores(pipe, param_grid, X_train_clust, y_train, verbose=3, return_params=True)
for scorer_name, scorer_results in results_clust.items():
    print(scorer_name)
    print(scorer_results)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# accuracy
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.290333      0.011108         0.016499        0.005766
#
#             param_feature_selection             param_pca      param_scaler  \
# 0  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'feature_selection': VarianceThreshold(thresh...           0.866567
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.885307            0.88081            0.88072         0.878351
#
#    std_test_score  rank_test_score
# 0        0.007052                1
# roc_auc
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.205404      0.005932         0.017751        0.003491
#
#             param_feature_selection             param_pca      param_scaler  \
# 0  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'feature_selection': VarianceThreshold(thresh...           0.981934
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.981899           0.983052           0.983496         0.982595
#
#    std_test_score  rank_test_score
# 0        0.000697                1
# f1_score
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.203236      0.011883          0.01225        0.002488
#
#             param_feature_selection             param_pca      param_scaler  \
# 0  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'feature_selection': VarianceThreshold(thresh...           0.866476
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.885796           0.881297           0.881058         0.878657
#
#    std_test_score  rank_test_score
# 0        0.007281                1

# %%
mdf_clust = merge_results(results_clust)

# Remove entries for fits that failed
mdf_clust = mdf_clust[~mdf_clust['mean_test_score'].isna()].sort_values(by='scorer')

# Save merged results to csv file
mdf_clust.to_csv(os.path.join(results_dir, 'gnb_clust_results.csv'), index=False)

mdf_clust.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.290333      0.011108         0.016499        0.005766
# 2       0.203236      0.011883         0.012250        0.002488
# 1       0.205404      0.005932         0.017751        0.003491
#
#             param_feature_selection             param_pca      param_scaler  \
# 0  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
# 2  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
# 1  VarianceThreshold(threshold=0.4)  PCA(n_components=32)  StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'feature_selection': VarianceThreshold(thresh...           0.866567
# 2  {'feature_selection': VarianceThreshold(thresh...           0.866476
# 1  {'feature_selection': VarianceThreshold(thresh...           0.981934
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.885307           0.880810           0.880720         0.878351
# 2           0.885796           0.881297           0.881058         0.878657
# 1           0.981899           0.983052           0.983496         0.982595
#
#    std_test_score  rank_test_score    scorer
# 0        0.007052                1  accuracy
# 2        0.007281                1  f1_score
# 1        0.000697                1   roc_auc

# %%
# There was a small improvement in accuracy and f1_score. Small decrease in roc_auc
# Conclusion: clustering is helpful to this model
print(best_params_clust)
# Out:
# {'feature_selection': VarianceThreshold(threshold=0.4), 'pca': PCA(n_components=32), 'scaler': StandardScaler()}

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Check final test scores on test data with best setup (w/ clustering)
best_model = GaussianNB(random_state=0)
y_pred = best_model.predict(X_test_clust)
y_pred_proba = best_model.predict_proba(X_test_clust)
best_acc = accuracy_score(y_test, y_pred)
best_f1 = f1_score(y_test, y_pred, average='weighted')
best_roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

best_scores = pd.DataFrame({
    'Accuracy': best_acc,
    'f1 Score': best_f1,
    'ROC AUC': best_roc_auc
})

best_scores
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39304\3157328723.py in <module>
#       2
#       3 # Check final test scores on test data with best setup (w/ clustering)
# ----> 4 best_model = GaussianNB(**best_params, random_state=0)
#       5 y_pred = best_model.predict(X_test_clust)
#       6 y_pred_proba = best_model.predict_proba(X_test_clust)
#
# TypeError: __init__() got an unexpected keyword argument 'feature_selection'
